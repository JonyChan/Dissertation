# %% [markdown]
# #### Tuesday Test

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread('/Users/chenxu/Desktop/YellowAnt.jpg')
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [254 254 254]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [254 254 254]
#   [255 255 255]
#   ...
#   [254 254 254]
#   [255 255 255]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
# test_color = cv.IMREAD_COLOR('/Users/chenxu/Desktop/YellowAnt.jpg')
# print(test_color)

# %%
# cv.imshow('image',img)
# cv.waitKey(0)
# cv.destroyAllWindows()

# %%
# cv.destroyWindow('image')

# %%
# from matplotlib import pyplot as plt

# %%
test_img = cv.imread('/Users/chenxu/Desktop/aaa.png')
# cv.namedWindow('image',0)
# cv.imshow('image',test_img)
# # k = cv.waitKey()
# k=cv.waitKey(0)
# if k == 10:
#     cv.destroyAllWindows()
# elif k == ord('s'):
#     cv.imwrite('/Users/chenxu/Desktop/aaa.png')
#     cv.destroyAllWindows()

# %% [raw]
# All of these are the opencv function, read, show and save one picture. There is a question that the showed picture coundn't be closed.

# %% [markdown]
# #### wednesday Test

# %%
px = test_img[100,100]
print(px)
# Out:
# [66 64 65]

# %%
blue = test_img[100,100,0]
print(blue)
# Out:
# 66

# %% [markdown]
# compute the value of the red Wrong

# %%
# test_img.item(10.10.2)

# %%
print(test_img.shape)
# Out:
# (794, 1162, 3)

# %%
print(test_img.size)
# Out:
# 2767884

# %%
print(img.dtype)
# Out:
# uint8

# %%
plt.subplot(221),
plt.imshow(test_img),
plt.title("Gray")

plt.subplot(222),
plt.imshow(test_img),
plt.title("Gray,too")

plt.subplot(223),
plt.imshow(img),
plt.title("ant")

plt.subplot(224),
plt.imshow(img),
plt.title("ant,too")

plt.show()

# %% [raw]
# image properties and plot pictures

# %%
from mpl_toolkits.mplot3d import Axes3D as A3D

# %%
fig = plt.figure()
ax = A3D(fig)
X = np.arange(0,4,0.25)
Y = np.arange(-4,0,0.25)
X,Y = np.meshgrid(X,Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X,Y,Z,rstride = 1, cstride = 1, cmap = "rainbow")

plt.show()

# %%
data = np.random.randint(0,255,size=[40,40,40])
# print(data[0])
X,Y,Z = data[0],data[1],data[2]
# ax = plt.subplot(111, projection='3d')

# ax.scatter(X[:10],Y[:10],Z[:10],c='y')

# ax.set_zlabel('r')
# ax.set_ylabel('g')
# ax.set_xlabel('b')

# plt.show()
print(X)
# Out:
# [[150 171  36 ... 226  77 206]
#  [241  83 156 ... 186 160  44]
#  [  0  39  73 ... 226 140  38]
#  ...
#  [234  22 119 ... 108  69 137]
#  [112 215 154 ... 106  22 135]
#  [139 200 186 ... 248  26 179]]

# %%
test_data = np.random.randint(0,10,size=(2,2))
print(test_data[1])
# Out:
# [5 0]

# %%
# ax = plt.subplot(111, projection = '3d')

# ax.scatter(0.3,0.5,0.8,c='r')
# ax.scatter(test_data[0],test_data[0],test_data[1],c='b')

# ax.set_zlabel('r')
# ax.set_ylabel('g')
# ax.set_xlabel('b')

# plt.show()

# %%
a = np.array([])
a = np.array([[1,2],[3,4],[5,6]])
print(a)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
b = np.empty((2,3,4))
print(b)

c = np.zeros((2,3))
print(c)
# Out:
# [[[-0.07047539 -0.05412152 -0.99055809  0.01976701]
#   [-0.08365497 -1.03688574  0.06824331 -0.03412165]
#   [-0.9591853  -0.01752742 -0.00876371 -0.91940757]]
#
#  [[-0.07430911  0.03715456 -1.04444251  0.02089545]
#   [ 0.01044773 -1.09607889  0.07183185  0.05516321]
#   [-1.00962364 -0.01840895  0.07790762 -0.96564843]]]
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
print(img.size)
# Out:
# 6525696

# %%
# for i in np.arange(img.size):
#     scalar = cv.CVGet2D(img,img.size)
# print(scalar)

# %%
print(np.arange(3))
# Out:
# [0 1 2]

# %%
b,g,r = img[694,1329]
print(b)
print(g)
print(r)
# Out:
# 56
# 65
# 79

# %%
rows, columns, channels = img.shape
print(rows)
print(columns)
print(channels)
# Out:
# 1172
# 1856
# 3

# %%
b_list = []
g_list = []
r_list = []
for i in np.arange(rows):
    for j in np.arange(columns):
        b,g,r = img[i,j]
        b_list.append(b)
        g_list.append(g)
        r_list.append(r)
#         print('the blue is in 'i + 'th and' j + 'th is ' b)

# %%
# test2004 = np.array([])
# np.insert(test2004,[1])
# # test2004.append([1])
# print(test2004)
a_list = [1]
a_list.append(2)

print(a_list[0])
# Out:
# 1

# %%
print(b_list[0:10])
# Out:
# [255, 255, 255, 255, 255, 255, 255, 255, 255, 255]

# %%
ax = plt.subplot(111, projection = '3d')

ax.scatter(b_list,g_list,r_list,c='r')
# ax.scatter(test_data[0],test_data[0],test_data[1],c='b')

ax.set_zlabel('r')
ax.set_ylabel('g')
ax.set_xlabel('b')

plt.show()

# %%
img2 = cv.imread('/Users/chenxu/Desktop/BlackGardenAnt.jpg')

rows2, columns2, channels2 = img2.shape
print(rows2)
print(columns2)
print(channels2)

b2_list = []
g2_list = []
r2_list = []

for i in np.arange(rows2):
    for j in np.arange(columns2):
        b2, g2, r2 = img2[i,j]
        b2_list.append(b2)
        g2_list.append(g2)
        r2_list.append(r2)
print(b2_list[777:888])

ax = plt.subplot(111, projection = '3d')

ax.scatter(b_list,g_list,r_list,c='r')
ax.scatter(b2_list,g2_list,r2_list,c='b')

ax.set_zlabel('r')
ax.set_ylabel('g')
ax.set_xlabel('b')

plt.show()
# Out:
# 379
# 612
# 3
# [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255]

# %%
print(type(b2_list))
# Out:
# <class 'list'>

# %%
# imgray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# thresh_value, thresh_pic = cv.threshold(imgray,127,255, cv.THRESH_BINARY)

# thresh_value, thresh_pic = cv.threshold(imgray,127,255,0)

# contours = cv.findContours(thresh_pic, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# contours, hierachy = cv.findContours(thresh_pic, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# print(contours)
# plt.imshow(contours)
# plt.show()
# cv.imshow('image',contours)

# cv.drawContours(img, contours, -1, (0,255,0), 3)

# cv.drawContours(img, contours, -1, (0,0,255), 3)

# %%
img_gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
value, pic = cv.threshold(img_gray,127,255,0)
all_points,contours,hierachy = cv.findContours(pic,cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# aa = cv.findContours(pic,cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# print(contours)
cv.drawContours(img,contours,-1,(0,0,255),1)

# cv.imshow('img',img_new)
# cv.waitKey(0)

plt.imshow(img)
plt.show()

# print(contours)

# %%
img_gray2 = cv.cvtColor(img2, cv.COLOR_BGR2GRAY)

value2, pic2 = cv.threshold(img_gray2,127,255,0)

all_points2, contours2, hierachy2 = cv.findContours(pic2, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
print(type(all_points))
print(type(contours2))
print(type(hierachy2))

cv.drawContours(img2, contours2, -1, (0,0,255),3)

plt.imshow(img2)
plt.show()
# Out:
# <class 'numpy.ndarray'>
# <class 'list'>
# <class 'NoneType'>

# %%
print(contours2)
# Out:
# []

# %%
print(hierachy2[0][0])
# Out:
# [ 6 -1  1 -1]

# %%
print(contours[0][0])
# Out:
# [[22 22]]

# %%
print(hierachy[0][0])
# Out:
# [-1 -1  1 -1]

# %%
print(hierachy.shape)
# Out:
# (1, 7, 4)

# %%
cnt = contours[1]
M = cv.moments(cnt)
print(type(M))
print(M)
# Out:
# <class 'dict'>
# {'m00': 6151.5, 'm10': 4168406.0, 'm01': 5102432.833333333, 'm20': 2829102803.75, 'm11': 3455135398.458333, 'm02': 4235732808.9166665, 'm30': 1923146964059.1, 'm21': 2343387809692.8, 'm12': 2866258909240.2, 'm03': 3519113331961.6504, 'mu20': 4489525.551837444, 'mu11': -2397176.8588519096, 'mu02': 3460872.205616951, 'mu30': -6320873.548095703, 'mu21': 4533755.810718536, 'mu12': 80131.64781951904, 'mu03': -5564793.847167969, 'nu20': 0.11864198136920415, 'nu11': -0.06334874563976939, 'nu02': 0.09145838040100987, 'nu30': -0.0021297299154825317, 'nu21': 0.0015275855949513498, 'nu12': 2.6999237722380135e-05, 'nu03': -0.0018749794375141815}

# %%
area = cv.contourArea(cnt)
print(type(area))
print(area)
# Out:
# <class 'float'>
# 6151.5

# %%
print(contours[1][0][0][1])
print(len(contours))
print(len(contours[0]))
print(contours[0][0][0][0])
print(contours[0][0][0][1])
# Out:
# 775
# 4
# 4
# 33
# 33

# %%
print(contours)
# Out:
# [array([[[  33,   33]],
#
#        [[  33, 1138]],
#
#        [[1822, 1138]],
#
#        [[1822,   33]]], dtype=int32), array([[[700, 775]],
#
#        [[701, 774]],
#
#        [[735, 808]],
#
#        [[735, 810]],
#
#        [[736, 811]],
#
#        [[735, 812]],
#
#        [[735, 815]],
#
#        [[699, 851]],
#
#        [[694, 851]],
#
#        [[674, 871]],
#
#        [[673, 871]],
#
#        [[672, 872]],
#
#        [[670, 872]],
#
#        [[667, 869]],
#
#        [[666, 869]],
#
#        [[654, 881]],
#
#        [[653, 881]],
#
#        [[651, 883]],
#
#        [[650, 883]],
#
#        [[616, 849]],
#
#        [[651, 814]],
#
#        [[652, 815]],
#
#        [[654, 813]],
#
#        [[657, 816]],
#
#        [[660, 813]],
#
#        [[660, 811]],
#
#        [[694, 777]],
#
#        [[695, 777]],
#
#        [[696, 776]],
#
#        [[697, 776]],
#
#        [[698, 775]]], dtype=int32), array([[[320, 358]],
#
#        [[321, 357]],
#
#        [[328, 357]],
#
#        ...,
#
#        [[315, 360]],
#
#        [[316, 360]],
#
#        [[318, 358]]], dtype=int32), array([[[1266,  476]],
#
#        [[1266,  477]],
#
#        [[1265,  478]],
#
#        [[1265,  483]],
#
#        [[1264,  484]],
#
#        [[1264,  486]],
#
#        [[1263,  487]],
#
#        [[1263,  492]],
#
#        [[1262,  493]],
#
#        [[1262,  496]],
#
#        [[1261,  497]],
#
#        [[1261,  499]],
#
#        [[1264,  499]],
#
#        [[1265,  498]],
#
#        [[1266,  499]],
#
#        [[1268,  499]],
#
#        [[1270,  497]],
#
#        [[1270,  496]],
#
#        [[1272,  494]],
#
#        [[1272,  493]],
#
#        [[1273,  492]],
#
#        [[1273,  491]],
#
#        [[1276,  488]],
#
#        [[1270,  482]],
#
#        [[1270,  481]],
#
#        [[1267,  478]],
#
#        [[1267,  477]]], dtype=int32)]

# %%
x = np.random.rand(10)
y = np.random.rand(10)
ax = plt.subplot()
ax.scatter(x,y, c = 'r')
plt.show()

# %%
x_list = []
y_list = []

for i in np.arange(len(contours)):
    for j in np.arange(len(contours[i])):
#         print(contours[i][j])
        x_list.append(contours[i][j][0][0])
        y_list.append(contours[i][j][0][1])
# Out:
# 2018

# %%
x2_list = []
y2_list = []

for i in

# %%
ax_shape = plt.subplot()
ax_shape.scatter(x_list,y_list)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
