# %% [markdown]
# #### Tuesday Test

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread('/Users/chenxu/Desktop/YellowAnt.jpg')
# print(img)

# %%
# test_color = cv.IMREAD_COLOR('/Users/chenxu/Desktop/YellowAnt.jpg')
# print(test_color)

# %%
# cv.imshow('image',img)
# cv.waitKey(0)
# cv.destroyAllWindows()

# %%
# cv.destroyWindow('image')

# %%
# from matplotlib import pyplot as plt

# %%
test_img = cv.imread('/Users/chenxu/Desktop/aaa.png')
# cv.namedWindow('image',0)
# cv.imshow('image',test_img)
# # k = cv.waitKey()
# k=cv.waitKey(0)
# if k == 10:
#     cv.destroyAllWindows()
# elif k == ord('s'):
#     cv.imwrite('/Users/chenxu/Desktop/aaa.png')
#     cv.destroyAllWindows()

# %% [raw]
# All of these are the opencv function, read, show and save one picture. There is a question that the showed picture coundn't be closed.

# %% [markdown]
# #### wednesday Test

# %%
px = test_img[100,100]
print(px)
# Out:
# [66 64 65]

# %%
blue = test_img[100,100,0]
print(blue)
# Out:
# 66

# %% [markdown]
# compute the value of the red Wrong

# %%
# test_img.item(10.10.2)

# %%
print(test_img.shape)
# Out:
# (794, 1162, 3)

# %%
print(test_img.size)
# Out:
# 2767884

# %%
print(img.dtype)
# Out:
# uint8

# %%
plt.subplot(221),
plt.imshow(test_img),
plt.title("Gray")

plt.subplot(222),
plt.imshow(test_img),
plt.title("Gray,too")

plt.subplot(223),
plt.imshow(img),
plt.title("ant")

plt.subplot(224),
plt.imshow(img),
plt.title("ant,too")

plt.show()

# %% [raw]
# image properties and plot pictures

# %%
from mpl_toolkits.mplot3d import Axes3D as A3D

# %%
fig = plt.figure()
ax = A3D(fig)
X = np.arange(0,4,0.25)
Y = np.arange(-4,0,0.25)
X,Y = np.meshgrid(X,Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X,Y,Z,rstride = 1, cstride = 1, cmap = "rainbow")

plt.show()

# %%
data = np.random.randint(0,255,size=[40,40,40])
# print(data[0])
X,Y,Z = data[0],data[1],data[2]
# ax = plt.subplot(111, projection='3d')

# ax.scatter(X[:10],Y[:10],Z[:10],c='y')

# ax.set_zlabel('r')
# ax.set_ylabel('g')
# ax.set_xlabel('b')

# plt.show()
# print(X)

# %%
test_data = np.random.randint(0,10,size=(2,2))
print(test_data[1])
# Out:
# [5 1]

# %%
# ax = plt.subplot(111, projection = '3d')

# ax.scatter(0.3,0.5,0.8,c='r')
# ax.scatter(test_data[0],test_data[0],test_data[1],c='b')

# ax.set_zlabel('r')
# ax.set_ylabel('g')
# ax.set_xlabel('b')

# plt.show()

# %%
a = np.array([])
a = np.array([[1,2],[3,4],[5,6]])
print(a)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
b = np.empty((2,3,4))
print(b)

c = np.zeros((2,3))
print(c)
# Out:
# [[[-0.07047539 -0.05412152 -0.99055809  0.01976701]
#   [-0.08365497 -1.03688574  0.06824331 -0.03412165]
#   [-0.9591853  -0.01752742 -0.00876371 -0.91940757]]
#
#  [[-0.07430911  0.03715456 -1.04444251  0.02089545]
#   [ 0.01044773 -1.09607889  0.07183185  0.05516321]
#   [-1.00962364 -0.01840895  0.07790762 -0.96564843]]]
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
print(img.size)
# Out:
# 6525696

# %%
# for i in np.arange(img.size):
#     scalar = cv.CVGet2D(img,img.size)
# print(scalar)

# %%
print(np.arange(3))
# Out:
# [0 1 2]

# %%
b,g,r = img[694,1329]
print(b)
print(g)
print(r)
# Out:
# 56
# 65
# 79

# %%
rows, columns, channels = img.shape
print(rows)
print(columns)
print(channels)
# Out:
# 1172
# 1856
# 3

# %%
b_list = []
g_list = []
r_list = []
for i in np.arange(rows):
    for j in np.arange(columns):
        b,g,r = img[i,j]
        b_list.append(b)
        g_list.append(g)
        r_list.append(r)
#         print('the blue is in 'i + 'th and' j + 'th is ' b)

# %%
# test2004 = np.array([])
# np.insert(test2004,[1])
# # test2004.append([1])
# print(test2004)
a_list = [1]
a_list.append(2)

print(a_list[0])
# Out:
# 1

# %%
print(b_list[0:10])
# Out:
# [255, 255, 255, 255, 255, 255, 255, 255, 255, 255]

# %%
fig = plt.figure(figsize = (18,18))

# ax_test = plt.subplot(111, projection = '3d')
ax_test = A3D(fig)

sValue = x*10

# ax_test.scatter([1,2],[2,3],[3,4],s = sValue,c='blue',marker = 'x')
ax_test.scatter([1,2],[2,3],[3,4],c='b',marker = 'x')
ax_test.scatter([1,3],[2,4],[3,5],c='y',marker = 'o')


ax_test.set_zlabel('r')
ax_test.set_ylabel('g')
ax_test.set_xlabel('b')

plt.legend('by')

plt.show()

# %%
print(np.random.seed(10))
# Out:
# None

# %%
ax = plt.subplot(111, projection = '3d')

sValue = x*10
ax.scatter(b_list,g_list,r_list,c='r',s=sValue)
# ax.scatter(test_data[0],test_data[0],test_data[1],c='b')

ax.set_zlabel('r')
ax.set_ylabel('g')
ax.set_xlabel('b')

plt.show()

# %%
img2 = cv.imread('/Users/chenxu/Desktop/BlackGardenAnt.jpg')

rows2, columns2, channels2 = img2.shape
# print(rows2)
# print(columns2)
# print(channels2)

b2_list = []
g2_list = []
r2_list = []

for i in np.arange(rows2):
    for j in np.arange(columns2):
        b2, g2, r2 = img2[i,j]
        b2_list.append(b2)
        g2_list.append(g2)
        r2_list.append(r2)
# print(b2_list[777:888])

ax = plt.subplot(111, projection = '3d')

ax.scatter(b_list,g_list,r_list,c='r',marker = 'o')
ax.scatter(b2_list,g2_list,r2_list,c='b', marker = 'x')

ax.set_zlabel('r_label')
ax.set_ylabel('g_label')
ax.set_xlabel('b_label')

plt.legend('YG')

plt.show()

# %%
fig_color = plt.figure(figsize = (12,12))
# ax_color = plt.subplot(111, projection = '3d')
#change the size of the coordinate
ax_color = A3D(fig_color)

#add label, change the style of representation and change the size of the point

sValue = x*10

ax_color.scatter(b_list,g_list,r_list,c='r',marker = 'o', label = 'YellowAnt', s = sValue)
ax_color.scatter(b2_list,g2_list,r2_list,c='b', marker = 'x', label = 'BlackAnt', s = sValue)

ax_color.set_zlabel('r_label')
ax_color.set_ylabel('g_label')
ax_color.set_xlabel('b_label')

plt.legend()

plt.show()

# %%
arr = np.array([])
# np.concatenate((arr,[1]),axis = 0)

# print(arr)

# %%
print(type(b2_list))
# Out:
# <class 'list'>

# %%
# imgray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# thresh_value, thresh_pic = cv.threshold(imgray,127,255, cv.THRESH_BINARY)

# thresh_value, thresh_pic = cv.threshold(imgray,127,255,0)

# contours = cv.findContours(thresh_pic, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# contours, hierachy = cv.findContours(thresh_pic, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# print(contours)
# plt.imshow(contours)
# plt.show()
# cv.imshow('image',contours)

# cv.drawContours(img, contours, -1, (0,255,0), 3)

# cv.drawContours(img, contours, -1, (0,0,255), 3)

# %%
img_gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
value, pic = cv.threshold(img_gray,127,255,0)
all_points,contours,hierachy = cv.findContours(pic,cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# aa = cv.findContours(pic,cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# print(contours)
cv.drawContours(img,contours,-1,(0,0,255),3)

# cv.imshow('img',img_new)
# cv.waitKey(0)

plt.imshow(img)
plt.show()

# print(contours)

# %%
img_gray2 = cv.cvtColor(img2, cv.COLOR_BGR2GRAY)

value2, pic2 = cv.threshold(img_gray2,127,255,0)

all_points2, contours2, hierachy2 = cv.findContours(pic2, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
print(type(all_points))
print(type(contours2))
print(type(hierachy2))

cv.drawContours(img2, contours2, -1, (0,0,255),3)

plt.imshow(img2)
plt.show()
# Out:
# <class 'numpy.ndarray'>
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
print(contours2)
# Out:
# [array([[[  0,   0]],
#
#        [[  0, 378]],
#
#        [[611, 378]],
#
#        [[611,   0]]], dtype=int32), array([[[243, 292]],
#
#        [[244, 291]],
#
#        [[245, 292]],
#
#        [[244, 293]]], dtype=int32), array([[[241, 292]],
#
#        [[242, 291]],
#
#        [[244, 293]],
#
#        [[243, 294]],
#
#        [[242, 294]],
#
#        [[241, 293]]], dtype=int32), array([[[456, 290]],
#
#        [[457, 289]],
#
#        [[458, 289]],
#
#        [[460, 291]],
#
#        [[459, 292]],
#
#        [[458, 292]]], dtype=int32), array([[[450, 286]],
#
#        [[451, 285]],
#
#        [[453, 287]],
#
#        [[452, 288]],
#
#        [[451, 288]],
#
#        [[450, 287]]], dtype=int32), array([[[250, 273]],
#
#        [[251, 272]],
#
#        [[253, 272]],
#
#        [[254, 273]],
#
#        [[252, 275]],
#
#        [[252, 276]],
#
#        [[253, 277]],
#
#        [[252, 278]],
#
#        [[251, 278]],
#
#        [[252, 279]],
#
#        [[251, 280]],
#
# ...

# %%
print(hierachy2[0][0])
# Out:
# [-1 -1  1 -1]

# %%
print(contours[0][0])
# Out:
# [[0 0]]

# %%
print(hierachy[0][0])
# Out:
# [-1 -1  1 -1]

# %%
print(hierachy.shape)
# Out:
# (1, 363, 4)

# %%
cnt = contours[1]
M = cv.moments(cnt)
print(type(M))
print(M)
# Out:
# <class 'dict'>
# {'m00': 223.0, 'm10': 156907.5, 'm01': 217529.8333333333, 'm20': 110435160.0, 'm11': 153061883.8333333, 'm02': 212196256.66666666, 'm30': 77749031224.75, 'm21': 107730776055.7, 'm12': 149312204718.33334, 'm03': 206995802572.85, 'mu20': 31735.980941697955, 'mu11': 3308.3905082046986, 'mu02': 2407.384030908346, 'mu30': -135118.5648803711, 'mu21': -76731.32839689776, 'mu12': -8242.189975521993, 'mu03': 1217.0148315429688, 'nu20': 0.6381785465562941, 'nu11': 0.06652839405989862, 'nu02': 0.04841006316049681, 'nu30': -0.18195033781307487, 'nu21': -0.10332622415744525, 'nu12': -0.011098913400194243, 'nu03': 0.0016388292750061171}

# %%
area = cv.contourArea(cnt)
print(type(area))
print(area)
# Out:
# <class 'float'>
# 223.0

# %%
print(contours[1][0][0][1])
print(len(contours))
print(len(contours[0]))
print(contours[0][0][0][0])
print(contours[0][0][0][1])
# Out:
# 970
# 363
# 4
# 0
# 0

# %%
print(contours)
# Out:
# [array([[[   0,    0]],
#
#        [[   0, 1171]],
#
#        [[1855, 1171]],
#
#        [[1855,    0]]], dtype=int32), array([[[679, 970]],
#
#        [[680, 969]],
#
#        [[685, 969]],
#
#        [[686, 970]],
#
#        [[689, 970]],
#
#        [[690, 971]],
#
#        [[691, 971]],
#
#        [[692, 972]],
#
#        [[694, 972]],
#
#        [[695, 973]],
#
#        [[697, 973]],
#
#        [[698, 974]],
#
#        [[705, 974]],
#
#        [[707, 976]],
#
#        [[705, 978]],
#
#        [[705, 980]],
#
#        [[707, 980]],
#
#        [[709, 978]],
#
#        [[709, 976]],
#
#        [[710, 975]],
#
#        [[711, 975]],
#
#        [[712, 974]],
#
#        [[713, 974]],
#
#        [[717, 970]],
#
#        [[720, 970]],
#
#        [[721, 971]],
#
#        [[721, 972]],
#
#        [[722, 973]],
#
#        [[722, 975]],
#
#        [[723, 976]],
#
#        [[722, 977]],
#
#        [[718, 977]],
#
#        [[716, 979]],
#
#        [[715, 979]],
#
#        [[713, 981]],
#
# ...

# %%
x = np.random.rand(10)
y = np.random.rand(10)
ax = plt.subplot()
# ax.legend()
ax.scatter(x,y, c = 'r')

plt.show()

# %%
x_list = []
y_list = []

for i in np.arange(len(contours)):
    for j in np.arange(len(contours[i])):
#         print(contours[i][j])
        x_list.append(contours[i][j][0][0]/3)
        y_list.append(contours[i][j][0][1]/3)

# %%
x2_list = []
y2_list = []

for i in np.arange(len(contours2)):
    for j in np.arange(len(contours2[i])):
        x2_list.append(contours2[i][j][0][0])
        y2_list.append(contours2[i][j][0][1])

# %%
ax_shape = plt.subplot()
ax_shape.scatter(x_list,y_list, c = 'r')
ax_shape.scatter(x2_list,y2_list, c = 'b' )
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ax_shape2 = plt.subplot()
ax_shape2.scatter(x_list,y_list, c = 'r', label = 'YellowAnt')
ax_shape2.scatter(x2_list,y2_list, c = 'b', label = 'BlackAnt')
plt.legend()
plt.title('two shapes of ants')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
